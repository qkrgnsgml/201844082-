# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
 
if __name__ == "__main__":
    RANK = 100
    result_df = pd.DataFrame()
 
    header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
    req = requests.get('https://www.melon.com/chart/index.htm', headers = header)
    html = req.text
    parse = BeautifulSoup(html, 'html.parser')
 
    titles = parse.find_all("div", {"class": "ellipsis rank01"})
    songs = parse.find_all("div", {"class": "ellipsis rank02"})
 
    title = []
    song = []
    rank = []
 
    for t in titles:
        title.append(t.find('a').text)
 
    for s in songs:
        song.append(s.find('span', {"class": "checkEllipsis"}).text)
 
    for i in range(RANK):
        rank.append(i+1);
        print('%3d위: %s - %s'%(i+1, title[i], song[i]))

    df = pd.DataFrame({'순위':rank,'곡명':title,'가수명':song})
    result_df = pd.concat([result_df, df], ignore_index=True)
    result_df.to_csv('melon.csv', encoding='euc-kr')
# Out:
#   1위: 사건의 지평선 - 윤하 (YOUNHA)
#   2위: 마이웨이 (MY WAY) (Prod. R.Tee) - 저스디스 (JUSTHIS), R.Tee, 던말릭 (DON MALIK), 허성현 (Huh), KHAN, 맥대디 (Mckdaddy), 로스 (Los)
#   3위: 사랑은 늘 도망가 - 임영웅
#   4위: Hype boy - NewJeans
#   5위: ANTIFRAGILE - LE SSERAFIM (르세라핌)
#   6위: London Boy - 임영웅
#   7위: 우리들의 블루스 - 임영웅
#   8위: Polaroid - 임영웅
#   9위: 다시 만날 수 있을까 - 임영웅
#  10위: 무지개 - 임영웅
#  11위: Nxde - (여자)아이들
#  12위: 이제 나만 믿어요 - 임영웅
#  13위: 아버지 - 임영웅
#  14위: A bientot - 임영웅
#  15위: After LIKE - IVE (아이브)
#  16위: Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound) - 정국, 방탄소년단
#  17위: 손이 참 곱던 그대 - 임영웅
#  18위: 인생찬가 - 임영웅
#  19위: 사랑해 진짜 - 임영웅
#  20위: 연애편지 - 임영웅
#  21위: 보금자리 - 임영웅
#  22위: 새삥 (Prod. ZICO) (Feat. 호미들) - 지코 (ZICO)
#  23위: Attention - NewJeans
#  24위: 위하여 (We Higher) (Prod. GroovyRoom) - 그루비룸 (GroovyRoom), 릴보이 (lIlBOI), Blase (블라세), 노윤하, Polodared, Chillin Homie, Fleeky Bang
#  25위: LOVE DIVE - IVE (아이브)
#  26위: Monologue - 테이
#  27위: Rush Hour (Feat. j-hope of BTS) - Crush
#  28위: Shut Down - BLACKPINK
#  29위: WE (Feat. 박재범) (Prod. by Slom) - 이영지, 토이고 (toigo), 제이켠 (J'Kyun), 잠비노 (Jambino), XINSAYNE
#  30위: WHEN I MOVE - 카라
#  31위: Pink Venom - BLACKPINK
#  32위: 해요 (2022) - #안녕
#  33위: 자격지심 (Feat. ZICO) - BE'O (비오)
#  34위: Snowman - Sia
#  35위: 들꽃놀이 (with 조유진) - RM
#  36위: 딱 10CM만 - 10CM, BIG Naughty (서동현)
#  37위: TOMBOY - (여자)아이들
#  38위: 잘가요 - 주호
#  39위: 내가 아니라도 - 주호
#  40위: 너의 모든 순간 - 성시경
#  41위: 사랑인가 봐 - 멜로망스
#  42위: Dynamite - 방탄소년단
#  43위: All I Want for Christmas Is You - Mariah Carey
#  44위: Cookie - NewJeans
#  45위: 그때 그 순간 그대로 (그그그) - WSG워너비 (가야G)
#  46위: 그라데이션 - 10CM
#  47위: FEARLESS - LE SSERAFIM (르세라핌)
#  48위: 그중에 그대를 만나 - 김호중
#  49위: 첫사랑 - 백아
#  50위: Butter - 방탄소년단
#  51위: 봄날 - 방탄소년단
#  52위: 아저씨 - 릴러말즈 (Leellamarz), 크루셜스타 (CRUCiAL STAR), QM, 김재욱, NSW yoon, 다민이 (DAMINI)
#  53위: 정이라고 하자 (Feat. 10CM) - BIG Naughty (서동현)
#  54위: Yet To Come - 방탄소년단
#  55위: The Astronaut - 진
#  56위: 떠나보낼 준비해 둘걸 그랬어 - 임한별
#  57위: Santa Tell Me - Ariana Grande
#  58위: 우린 그렇게 사랑해서 - 강민경 (다비치), 잔나비 최정훈
#  59위: 나의 목소리로 - 김호중
#  60위: 취중고백 - 김민석 (멜로망스)
#  61위: 흩어지지 않게 - 엠씨더맥스 (M.C the MAX)
#  62위: ELEVEN - IVE (아이브)
#  63위: 나의 X에게 - 경서
#  64위: Permission to Dance - 방탄소년단
#  65위: That's Hilarious - Charlie Puth
#  66위: 보고싶었어 - WSG워너비 (4FIRE)
#  67위: 다정히 내 이름을 부르면 - 경서예지, 전건호
#  68위: 내 기쁨은 너가 벤틀리를 끄는 거야 - 김승민
#  69위: I Don't Think That I Like Her - Charlie Puth
#  70위: 인생은 뷰티풀 - 김호중
#  71위: 새벽에 걸려온 너의 전화는 - 한동근
#  72위: LOVE me - BE'O (비오)
#  73위: 첫 눈 - EXO
#  74위: 모든 날, 모든 순간 (Every day, Every Moment) - 폴킴
#  75위: 주마등 - 김호중
#  76위: 주저하는 연인들을 위해 - 잔나비
#  77위: Last Christmas - Ariana Grande
#  78위: 밤하늘의 별을(2020) - 경서
#  79위: 빛이 나는 사람 - 김호중
#  80위: 봄여름가을겨울 (Still Life) - BIGBANG (빅뱅)
#  81위: STAY - The Kid LAROI, Justin Bieber
#  82위: That That (prod. & feat. SUGA of BTS) - 싸이 (PSY)
#  83위: FOREVER 1 - 소녀시대 (GIRLS' GENERATION)
#  84위: 고백연습 - 경서
#  85위: Love story - 볼빨간사춘기
#  86위: 친구 - 김호중
#  87위: 약속 [約束] - 김호중
#  88위: 도깨비불 (Illusion) - aespa
#  89위: 슬픈등 - 김호중
#  90위: 사랑한다고 말해줘 - 탑현
#  91위: SNEAKERS - ITZY (있지)
#  92위: Left and Right (Feat. Jung Kook of BTS) - Charlie Puth, 정국, 방탄소년단
#  93위: Feel My Rhythm - Red Velvet (레드벨벳)
#  94위: Birthday - Red Velvet (레드벨벳)
#  95위: 미리 메리 크리스마스 (Feat. 천둥 Of MBLAQ) - 아이유
#  96위: 오르트구름 - 윤하 (YOUNHA)
#  97위: Il Mare Calmo Della Sera - 김호중
#  98위: Off My Face - Justin Bieber
#  99위: Tiritomba - 김호중
# 100위: 가을꽃 - 김호중

# %%
from google.colab import drive
drive.mount('/content/drive')
